# %% [markdown]
# # scikit-image tutorial
#
# ![skimage logo](skimage_logo.png)
#
# ## Euroscipy 2017
#
# Licensed under CC BY 4.0 Creative Commons
#
# ## About me: Emmanuelle Gouillart
#
# * researcher in materials science: glass at high temperature, 3-D imaging (tomography)
# * scikit-image core contributor
# * GitHub [@emmanuelle](https://github.com/emmanuelle), Twitter [@EGouillart](https://twitter.com/EGouillart)
#
# ### Outline
#
# An introduction to image processing with scikit-image : slides [euroscipy.pdf](euroscipy.pdf) in this folder.
#
# [Images as digital arrays](arrays.ipynb)
#
# [Image visualization](visualization.ipynb)
#
# [Image exposure and thresholding](pixel_values.ipynb)
#
# [Image filtering and segmentation](neighbors.ipynb)
#
# Bonus (if you already know all this):
#
# [Image warping (geometrical transformations](adv4_warping.ipynb)
#
# [Panorama stitching](adv3_panorama-stitching.ipynb)
#
# ## After the tutorial
#
# Stay in touch!
#
# - Follow the project's progress [on GitHub](https://github.com/scikit-image/scikit-image).
# - Ask the team questions on the [mailing list](https://groups.google.com/d/forum/scikit-image)
# - [Contribute!](https://github.com/scikit-image/scikit-image/blob/master/CONTRIBUTING.txt)
# - If you find it useful: cite [our paper](https://peerj.com/articles/453/)!
#
# ## Test your installation

# %%
import skimage

# %%
from skimage import data, io

# %%
cat = data.chelsea()

# %%
# %matplotlib inline
io.imshow(cat)
